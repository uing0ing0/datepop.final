# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

# %%
# Setting
location = "강남역"
keyword = "맛집"
low_rate = 70 # 하위 70% 이상

columns_to_zero = ['instagram_post', 'instagram_follower',
                   'visitor_review_count', 'blog_review_count', 'distance_from_subway']

columns_to_false = ['on_tv', 'seoul_michelin', 'on_blue_ribbon', "no_kids",
                    "parking_available", "hot_spot", "age-2030", "gender-balance", "new_store"]

def calculate_consine_similarity(df1, df2):
    return cosine_similarity(df1, df2)

# Data Loading

crawled_data = pd.read_csv(
    f"data/crawl_result/{location}{keyword}.csv", header=0, encoding='utf-8-sig').drop('Unnamed: 0', axis=1).reset_index(drop=True)

datepop_data = pd.read_csv(
    f"data/datepop/shop_food.csv", header=0, encoding='utf-8-sig').drop('Unnamed: 0', axis=1).reset_index(drop=True)

for column in columns_to_zero:
    crawled_data[column].fillna(0, inplace=True)
    datepop_data[column].fillna(0, inplace=True)
for column in columns_to_false:
    crawled_data[column].fillna(False, inplace=True)
    datepop_data[column].fillna(False, inplace=True)

crawled_data.reset_index(drop=True, inplace=True)
datepop_data.reset_index(drop=True, inplace=True)

# Type Conveersion
str_to_int_features = ['instagram_post', 'instagram_follower', 'visitor_review_count', 'blog_review_count', 'distance_from_subway']

for feature in str_to_int_features:
    crawled_data[feature] = crawled_data[feature].astype(int)
    datepop_data[feature] = datepop_data[feature].astype(int)

handled_data = crawled_data.copy()


# Feature Scaling
numeric_features = ['instagram_post', 'instagram_follower', 'visitor_review_count', 'blog_review_count', 'distance_from_subway']
scaler = MinMaxScaler()

handled_data[numeric_features] = scaler.fit_transform(handled_data[numeric_features])
datepop_data[numeric_features] = scaler.transform(datepop_data[numeric_features])

# Similarity Calculation
similarity_features = ['instagram_post', 'instagram_follower', 'visitor_review_count', 'blog_review_count', 
                       'distance_from_subway', 'new_store', 'gender-balance', 'age-2030', 'hot_spot', 
                       'parking_available', 'no_kids', 'on_tv', 'seoul_michelin', 'on_blue_ribbon']

average_similarity = []
for i, row in handled_data.iterrows():
    row_df = pd.DataFrame([row[similarity_features]])
    similarities = calculate_consine_similarity(row_df, datepop_data[similarity_features])[0]

    high_percent = np.percentile(similarities, low_rate)
    top_similarities = [sim for sim in similarities if sim >= high_percent]
    average_similarity.append(np.mean(top_similarities))

crawled_data.insert(3, 'similarity', average_similarity)
# pd.DataFrame(average_similarity).describe()

# %% [markdown]
# ### 6. Total score

# %%
total_scores = []
for index, item in crawled_data.iterrows():
    score1 = math.pow(100, item["similarity"])
    total_scores.append(score1)

crawled_data.insert(4, 'total_score', total_scores)
crawled_data.sort_values(by="total_score", ascending=False,
                            ignore_index=True, inplace=True)
# Out:
#       store_id              name category  similarity  total_score  is_food  \
# 0   1317157725         레뽀드라라 강남점       카페    0.928796    72.043170     True
# 1   1712856289           류센소 강남점    일본식라면    0.928435    71.923271     True
# 2     19948255           진대감 역삼점    소고기구이    0.925823    71.063291     True
# 3   1853785709  배드라핀 [Bad Lapin]       와인    0.924342    70.580451     True
# 4   1136933064              호보식당       한식    0.914820    67.552420     True
# 5   1932467805  보글이 생태탕왕코다리 양재역점  해물,생선요리    0.912736    66.907162     True
# 6   1912493531             데일리픽스       양식    0.906885    65.128288     True
# 7   1381311081         진짜해산물 역삼점     조개요리    0.902690    63.882104     True
# 8   1081029406           쇼쿠지 양재점      일식당    0.901945    63.663310     True
# 9   1882132325            비아살라리아     베이커리    0.901327    63.482575     True
# 10  1668757640        퍼스트커피랩 강남점   카페,디저트    0.899313    62.896351     True
# 11    19867427               푸주옥   곰탕,설렁탕    0.897583    62.397279     True
# 12  1044112634             나이스샤워      일식당    0.896140    61.983977     True
# 13  1260383017         함양숯불회관 본점       한식    0.879772    57.483694     True
# 14  1754912649              강남명전    전,빈대떡    0.870767    55.148552     True
# 15  1257285078          가가솥밥 강남점       한식    0.870717    55.135955     True
# 16  1067283876             어퍼앤언더   카페,디저트    0.870648    55.118389     True
# 17  1305729290         맛깔시장 강남역점     포장마차    0.870617    55.110505     True
# 18  1058321879          한라맥주 강남점    맥주,호프    0.870162    54.995188     True
# 19  1537200954          나이쏘이 강남점     태국음식    0.869634    54.861590     True
#
#     new_store                                     instagram_link  \
# 0       False            https://www.instagram.com/repos_de_lala
# 1       False         https://www.instagram.com/ryusenso.gangnam
# 2       False       https://www.instagram.com/jindaegam_official
# 3       False                https://www.instagram.com/badlapin_
# 4       False             https://instagram.com/hobo__restaurant
# 5       False                                                NaN
# 6       False          https://www.instagram.com/daily.fix.seoul
# 7       False          https://www.instagram.com/jinhae_official
# 8       False                                                NaN
# 9       False              https://www.instagram.com/via_salaria
# 10      False  https://www.instagram.com/firstcoffee_lab_gangnam
# 11      False                                                NaN
# 12      False                                                NaN
# 13      False                                                NaN
# 14      False                    http://instagram.com/gnmj._.jmt
# 15      False               https://www.instagram.com/gagasotbab
# 16      False                                                NaN
# 17      False   https://www.instagram.com/matggalmarket_official
# 18      False        https://www.instagram.com/hallabeer_gangnam
# 19      False          https://www.instagram.com/naisoi_official
#
#     instagram_post  instagram_follower  ...  no_kids  pet_available  \
# 0               82                 251  ...    False          False
# 1                9                  88  ...    False          False
# 2              128                2176  ...    False          False
# 3               25                1593  ...    False          False
# 4              173                 661  ...    False          False
# 5                0                   0  ...    False          False
# 6              108                1093  ...    False           True
# 7               40                1108  ...    False          False
# 8                0                   0  ...    False          False
# 9               12                 312  ...    False           True
# 10              28                 294  ...    False          False
# 11               0                   0  ...    False          False
# 12               0                   0  ...    False          False
# 13               0                   0  ...    False          False
# 14              75                 765  ...    False          False
# 15              86                 661  ...    False          False
# 16               0                   0  ...    False          False
# 17              24                  63  ...    False          False
# 18              47                 140  ...    False          False
# 19              88                1196  ...    False          False
#
#     seoul_michelin  age-2030  gender-balance  on_blue_ribbon  \
# 0            False     False           False           False
# 1            False     False           False           False
# 2            False     False           False           False
# 3            False     False           False           False
# 4            False     False           False           False
# 5            False     False           False           False
# 6            False     False           False           False
# 7            False     False           False           False
# 8            False     False           False           False
# 9            False     False           False           False
# 10           False     False           False           False
# 11           False     False           False           False
# 12           False     False           False           False
# 13           False     False           False           False
# 14           False     False           False           False
# 15           False     False           False           False
# 16           False     False           False           False
# 17           False     False           False           False
# 18           False     False           False           False
# 19           False     False           False           False
#
#                                            image_urls  \
# 0   ['https://search.pstatic.net/common/?autoRotat...
# 1   ['https://search.pstatic.net/common/?autoRotat...
# 2   ['https://search.pstatic.net/common/?autoRotat...
# 3   ['https://search.pstatic.net/common/?autoRotat...
# 4   ['https://search.pstatic.net/common/?autoRotat...
# 5   ['https://search.pstatic.net/common/?autoRotat...
# 6   ['https://search.pstatic.net/common/?autoRotat...
# 7   ['https://search.pstatic.net/common/?autoRotat...
# 8   ['https://search.pstatic.net/common/?autoRotat...
# 9   ['https://search.pstatic.net/common/?autoRotat...
# 10  ['https://search.pstatic.net/common/?autoRotat...
# 11  ['https://search.pstatic.net/common/?autoRotat...
# 12  ['https://search.pstatic.net/common/?autoRotat...
# 13  ['https://search.pstatic.net/common/?autoRotat...
# 14  ['https://search.pstatic.net/common/?autoRotat...
# 15  ['https://search.pstatic.net/common/?autoRotat...
# 16  ['https://search.pstatic.net/common/?autoRotat...
# 17  ['https://search.pstatic.net/common/?autoRotat...
# 18  ['https://search.pstatic.net/common/?autoRotat...
# 19  ['https://search.pstatic.net/common/?autoRotat...
#
#                              address           phone  \
# 0           서울 강남구 테헤란로7길 22 2관 101호  0507-1352-3177
# 1              서울 강남구 강남대로102길 31 1층  0507-1342-8725
# 2               서울 강남구 봉은사로30길 75 1층  0507-1346-2472
# 3             서울 강남구 논현로97길 23 1층 카페  0507-1310-7913
# 4                서울 강남구 논현로85길 43 1층     02-508-3992
# 5   서울 서초구 강남대로37길 56-18 서초에메랄드빌딩 1층  0507-1388-7709
# 6           서울 강남구 논현로85길 70 1층 102호  0507-1346-2468
# 7              서울 강남구 언주로81길 8 1층 2호  0507-1351-3943
# 8                 서울 서초구 서운로6길 19 1층  0507-1349-8740
# 9          서울 강남구 역삼로7길 10 융전빌딩 101호  0507-1431-2297
# 10               서울 강남구 봉은사로6길 39 1층     02-555-7679
# 11          서울 서초구 서초중앙로26길 5 1층 푸주옥     02-596-2350
# 12          서울 강남구 테헤란로10길 25 뜨라네아파트  0507-1335-6008
# 13               서울 강남구 역삼로 140 지상1층  0507-1420-9234
# 14         서울 서초구 서초대로75길 36 대청빌딩 2층  0507-1363-3371
# 15                서울 강남구 역삼로5길 19 1층  0507-1480-7903
# 16   서울 강남구 강남대로102길 28 지하1층, 1층, 2층     02-557-6991
# 17       서울 서초구 강남대로65길 12 지하1층 맛깔시장   010-9171-6669
# 18              서울 강남구 봉은사로18길 90 1층  0507-1317-1789
# 19             서울 강남구 강남대로102길 11 2층  0507-1385-9923
#
#                                                   gps
# 0   {'latitude': 37.5003173, 'longitude': 127.0306...
# 1   {'latitude': 37.50309500000002, 'longitude': 1...
# 2   {'latitude': 37.5027032, 'longitude': 127.0371...
# 3   {'latitude': 37.5028125549704, 'longitude': 12...
# 4   {'latitude': 37.4980897, 'longitude': 127.0346...
# 5   {'latitude': 37.4854129, 'longitude': 127.0305...
# 6    {'latitude': 37.4976844, 'longitude': 127.03257}
# 7   {'latitude': 37.5003645, 'longitude': 127.0428...
# 8   {'latitude': 37.485876384532716, 'longitude': ...
# 9   {'latitude': 37.4948832, 'longitude': 127.0331...
# 10  {'latitude': 37.5026909, 'longitude': 127.0279...
# 11  {'latitude': 37.4956371, 'longitude': 127.0140...
# 12   {'latitude': 37.497612, 'longitude': 127.032939}
# 13  {'latitude': 37.4943324, 'longitude': 127.0348...
# 14  {'latitude': 37.5007702, 'longitude': 127.0251...
# 15  {'latitude': 37.49507299798022, 'longitude': 1...
# 16  {'latitude': 37.5027449, 'longitude': 127.0276...
# 17  {'latitude': 37.5005224, 'longitude': 127.0247...
# 18  {'latitude': 37.50083197382796, 'longitude': 1...
# 19  {'latitude': 37.5019284, 'longitude': 127.026722}
#
# [20 rows x 26 columns]

# %%
# crawled_data.head(20).to_csv(f'data/crawl_score/only_similarity/{location}{keyword}_top20_{low_rate}.csv', encoding='utf-8-sig')
